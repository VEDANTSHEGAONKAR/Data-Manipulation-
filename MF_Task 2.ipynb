# %% [markdown]
# # MainFlow Services and Technlogies
# ### Data Science using Python
# Task 2 : This task involves using the Pandas
#         library to manipulate data.
# Used libraries
# 1. Pandas
# 2. Numpy

# %%
#importing Libraries

import pandas as pd
import numpy as np

# %%
# Importing CSV File
df=pd.read_csv("D:\Main flow assingments\Data\\01.Data Cleaning and Preprocessing.csv")
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0       1-10:00    12.17    12.667     114.570  1253.584      188.043
# 1       1-07:00    12.48    15.950      77.543  1190.289      189.957
# 2       1-11:00    12.81    10.942     114.567  1241.142      215.485
# 3       7-05:00    13.48    13.633     105.911  1232.975      169.841
# 4       1-09:00    13.49    13.700      98.186  1243.688      116.275
# ..          ...      ...       ...         ...       ...          ...
# 319    31-11:00    26.62    15.467      84.447  1334.255      386.971
# 320     1-15:00    27.10    13.558      83.117  1175.417      289.256
# 321    31-12:00    27.20    16.083      82.839  1332.331      366.855
# 322    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 323    31-01:00    27.60    16.810      79.022  1328.360      341.327
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#Checking columns
df.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
#analyzing the duplicate values
df.dtypes
y=df[df.duplicated()]
y
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 5       1-09:00    13.49    13.700      98.186  1243.688      116.275
# 8       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 23      8-14:00    16.05    13.114         NaN       NaN        0.000
# 37      8-13:00    16.70       NaN         NaN       NaN        0.000
# 57      8-15:00    17.75    11.283         NaN       NaN       41.607
# 64      4-16:00    17.80    16.625      78.367  1276.082      202.744
# 76      4-17:00    18.20    16.283      83.508  1288.104      234.284
# 119     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 221    31-07:00    22.50    14.233      97.249  1346.900      330.325
# 224    31-09:00    22.60    13.875      95.720  1351.240      383.731
# 227    31-06:00    22.65    14.100      91.887  1307.852      288.989
# 234    31-04:00    22.90    15.618      93.244  1334.168      243.131
# ...

# %%
#filtering the data frame using  a condition
filtered_df=df[df["Y-Kappa"]>16]
filtered_df.head()
# Out:
#    Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 22     8-14:00    16.05    13.114         NaN       NaN        0.000
# 23     8-14:00    16.05    13.114         NaN       NaN        0.000
# 24     1-06:00    16.10    16.292      68.645  1094.883      245.962
# 25     3-04:00    16.10    12.875      92.117  1236.216      268.214
# 26     8-04:00    16.10    13.442      95.320  1206.594      182.284
#
#     T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 22            NaN             NaN  1.648       500.376  ...        55.180
# 23            NaN             NaN  1.648       500.376  ...        55.180
# 24        344.478         321.061  1.571       509.786  ...        60.236
# 25        357.194         320.715  1.300       609.985  ...        68.430
# 26        369.106         333.807    NaN       630.635  ...        65.347
#
#     Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
#new data frame for cleaning
new_df=pd.read_csv("D:\Main flow assingments\Data\\01.Data Cleaning and Preprocessing.csv")

# %%
new_df["ChipRate"].dtype
# Out:
# dtype('float64')

# %%
#Cheaking the empty vales
new_df.isna().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
#handeling empty values 
new_df["ChipRate"].fillna(new_df["ChipRate"].mean(),inplace=True)

# %%
new_df.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  324.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.487447    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.364750   81.823000  1193.215250   213.527000
# 50%     20.845000   14.347937   86.739000  1273.138500   271.792000
# 75%     23.032500   15.498250   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
filePath_export=r"D:\Main flow assingments\Data\\01.Data Cleaning and Preprocessing exported.csv"
new_df.to_csv(filePath_export)
